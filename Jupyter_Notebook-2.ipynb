# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Chandrakanth Tolupunoori** <br> Data Analyst

# %% [markdown]
# *I am interested in data science because, I love finding insights by analyzing huge volumes of data and adding business value.*

# %% [markdown]
# ### Find if a number is even or odd

# %%
#Take User Input
num = int(input("Enter a number: "))
if (num % 2) == 0:
   print("{0} is Even".format(num))
else:
   print("{0} is Odd".format(num))

# %% [markdown]
# My favorite things to do include:<br>
# - Playing Badminton
# - Hiking
# - Long drives
#
# ***
#
# __https://numpy.org/doc/stable/index.html__
#
#
# ![image.jpeg](attachment:9051eea7-5fa1-4dd7-88d6-0e9a5999b279.jpeg)
